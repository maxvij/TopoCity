# %%
import time
from flask import Flask, request, jsonify
from collections import namedtuple
import pandas as pd
import json
from pytrends.request import TrendReq
import requests
from statistics import mean
import sys
from tqdm import tqdm

# %% [markdown]
# ### nxn+1 distance+popularity matrix

# %%
pytrend = TrendReq()
startTime = time.time()

# %%
cities = pd.read_csv('cities_20k.csv')

# %%
cities.head()
# Out:
#    Unnamed: 0 Woonplaatsen Provincie                  Landsdeel  \
# 0          12        Assen   Drenthe  Noord-Nederland
# 1          29    Coevorden   Drenthe  Noord-Nederland
# 2          64        Emmen   Drenthe  Noord-Nederland
# 3          98    Hoogeveen   Drenthe  Noord-Nederland
# 4         115       Meppel   Drenthe  Noord-Nederland
#
#                               Gemeente   Latitude  Longitude  Population  \
# 0  Assen                                52.983333   6.550000       68798
# 1  Coevorden                            52.650000   6.733333       35303
# 2  Emmen                                52.783333   6.900000       56545
# 3  Hoogeveen                            52.716667   6.466667       40190
# 4  Meppel                               52.700000   6.183333       34125
#
#              Coordinates
# 0  52° 59′ NB, 6° 33′ OL
# 1  52° 39′ NB, 6° 44′ OL
# 2  52° 47′ NB, 6° 54′ OL
# 3  52° 43′ NB, 6° 28′ OL
# 4  52° 42′ NB, 6° 11′ OL

# %%
city_names = cities['Woonplaatsen'].unique()
len_city_names = len(city_names)
popularity = [0] * len_city_names

# %%
new_df = pd.DataFrame(list(zip(city_names, popularity)), columns = ['City', 'Popularity'])

# %%
new_df.head()
# Out:
#         City  Popularity
# 0      Assen           0
# 1  Coevorden           0
# 2      Emmen           0
# 3  Hoogeveen           0
# 4     Meppel           0

# %%
new_df['City'] = city_names

# %%
new_df['Popularity'] = popularity

# %%
new_df.head()
# Out:
#         City  Popularity
# 0      Assen           0
# 1  Coevorden           0
# 2      Emmen           0
# 3  Hoogeveen           0
# 4     Meppel           0

# %%
for index, row in new_df.iterrows():
    # print(row['c1'], row['c2'])
    popularity = pytrend.build_payload([row['City']], cat=0, timeframe='today 5-y', geo='', gprop='')
    interest_df = pytrend.interest_over_time()
    interest = mean(interest_df[row['City']])
    print(interest)
    new_df.loc[index, 'Popularity'] = interest
# Out:
# 20.203846153846154
# 48.12307692307692
# 60.12307692307692
# 76.37307692307692
# 51.026923076923076
# 73.45384615384616
# 73.08461538461539
# 73.70769230769231
# 65.5576923076923
# 18.1
# 17.546153846153846
# 62.59615384615385
# 43.57692307692308
# 46.63846153846154
# 67.75769230769231
# 76.48076923076923
# 77.82307692307693
# 25.023076923076925
# 54.52307692307692
# 61.15384615384615
# 76
# 43.10769230769231
# 80.51923076923077
# 68.47692307692307
# 63.83461538461538
# 69.88461538461539
# 77.01153846153846
# 62.90384615384615
# 48.823076923076925
# 67.76923076923077
# 74.17307692307692
# 49.22692307692308
# 69.62307692307692
# 65.31153846153846
# 68.42692307692307
# 72.03846153846153
# 80.19615384615385
# 50.565384615384616
# 74.29230769230769
# 63.2
# 48.91153846153846
# 64.26923076923077
# 66.03076923076924
# 61.40384615384615
# 72.69615384615385
# 46.63076923076923
# 71.35384615384615
# 58.62692307692308
# 61.68846153846154
# 72.3923076923077
# 75
# 73.45769230769231
# 73.73076923076923
# 80.09615384615384
# 47.11153846153846
# 76.04615384615384
# 79.71923076923076
# 44.003846153846155
# 76.41153846153846
# 72.41923076923077
# 70.43846153846154
# 68.5
# 31.423076923076923
# 7.492307692307692
# 50.87692307692308
# 75.22307692307692
# 28.396153846153847
# 82.78846153846153
# 26.65
# 64.86923076923077
# 72.86538461538461
# 83.35384615384615
# 72.6076923076923
# 74.83076923076923
# 73.02692307692308
# 63.76538461538462
# 58.534615384615385
# 78.89615384615385
# 27.16923076923077
# 79.76538461538462
# 82.22307692307692
# 69.89615384615385
# 74.4
# 67.93846153846154
# 20.326923076923077
# 62.36538461538461
# 57.67307692307692
# 42.58076923076923
# 80.43461538461538
# 68.54615384615384
# 76.9423076923077
# 65.47307692307692
# 73.71153846153847
# 56.61538461538461
# 79.4
# 69.39615384615385
# 75.78846153846153
# 81.74615384615385
# 65.54615384615384
# 27.74230769230769
# 77.63846153846154
# 66.08461538461539
# ---------------------------------------------------------------------------
# ResponseError                             Traceback (most recent call last)
# <ipython-input-11-69f140532311> in <module>
#       1 for index, row in new_df.iterrows():
#       2     # print(row['c1'], row['c2'])
# ----> 3     popularity = pytrend.build_payload([row['City']], cat=0, timeframe='today 5-y', geo='', gprop='')
#       4     interest_df = pytrend.interest_over_time()
#       5     interest = mean(interest_df[row['City']])
#
# ~\Anaconda3\lib\site-packages\pytrends\request.py in build_payload(self, kw_list, cat, timeframe, geo, gprop)
#     167         self.token_payload['req'] = json.dumps(self.token_payload['req'])
#     168         # get tokens
# --> 169         self._tokens()
#     170         return
#     171
#
# ~\Anaconda3\lib\site-packages\pytrends\request.py in _tokens(self)
#     177             method=TrendReq.GET_METHOD,
#     178             params=self.token_payload,
# --> 179             trim_chars=4,
#     180         )['widgets']
#     181         # order of the json matters...
#
# ~\Anaconda3\lib\site-packages\pytrends\request.py in _get_data(self, url, method, trim_chars, **kwargs)
#     146                 'The request failed: Google returned a '
#     147                 'response with code {0}.'.format(response.status_code),
# --> 148                 response=response)
#     149
#     150     def build_payload(self, kw_list, cat=0, timeframe='today 5-y', geo='',
#
# ResponseError: The request failed: Google returned a response with code 429.

# %%
new_df.head()
# Out:
#         City  Popularity
# 0      Assen   20.203846
# 1  Coevorden   48.123077
# 2      Emmen   60.123077
# 3  Hoogeveen   76.373077
# 4     Meppel   51.026923

# %%
all_jobs = len_city_names * len_city_names
count = 1
toolbar_width = 40


for col in city_names:
    column = []
    start_time = time.time()
    for row in city_names:
        
        uri = "https://www.distance24.org/route.json?stops=" + str(col).strip() + '|' + str(row).strip()
        url = uri.strip()
        try:
            uResponse = requests.get(url)
        except requests.ConnectionError:
            print ('error')  
        Jresponse = uResponse.text
        data = json.loads(Jresponse)
        distance = data['distance']
        column.append(distance)
        division = count/all_jobs
        #print (str(count) + '/' + str(all_jobs))
        count+=1
        #print(column)
    end_time = time.time()
    print("total time taken this loop: ", end_time - start_time)
    new_df[col] = column
# Out:
# 1/33489
# 2/33489
# 3/33489
# 4/33489
# 5/33489
# 6/33489
# 7/33489
# 8/33489
# 9/33489
# 10/33489
